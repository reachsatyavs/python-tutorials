# %%
f = open("names.txt")
print(type(f.readlines()))
for l in f.readlines():
    print(l)
f.close()
# Out:
# <class 'list'>

# %%
f = open("names.txt")
print(f.read())
f.close()
print("=====Before====")

f = open("names.txt",'a')
f.write("Murali \n")
f.write("Sudhakar")
f.close()

print("=====After====")
f = open("names.txt")
print(f.read())
f.close()
# Out:
# rajeev
# satya
# sankar
# madhu
#
# =====Before====
# =====After====
# rajeev
# satya
# sankar
# madhu
# Murali
# Sudhakar

# %%
import os
f = os.path.exists("names1.txt")
print(type(f))
print(f)

f = os.path.getsize("names1.txt")
print(f)


for f in os.listdir("../"):
    print(f.sort())
# Out:
# <class 'bool'>
# True
# 6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 11
#       7 print(f)
#       8
#       9
#      10 for f in os.listdir("../"):
# ---> 11     print(f.sort())
#      12
#      13
#      14
#
# AttributeError: 'str' object has no attribute 'sort'
